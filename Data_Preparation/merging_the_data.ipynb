# %%
import pandas as pd

combined = pd.read_csv("combined_with_hotels.csv")
new_data = pd.read_csv("/content/improved_neutral_aspects.csv")

# %%
all = pd.concat([combined,new_data])
all
# Out:
#       domain_name  unified_sentiment  \
# 0     Attractions                1.0
# 1     Attractions                1.0
# 2     Attractions                1.0
# 3     Attractions                1.0
# 4     Attractions                1.0
# ...           ...                ...
# 3195       Hotels                0.0
# 3196       Hotels                1.0
# 3197  Restaurants                0.0
# 3198  Restaurants                0.0
# 3199  Restaurants                0.0
#
#                                         Sentences_clean  \
# 0     نصحوني بتجربه حمام الكبريت يمكنكم الدخول مع مج...
# 1     قلعه ساحره منظر خلاب للمدينه من اعلي القلعه يو...
# 2     تبليسي جورجيا من اجمل المدن التي زرتها في حيات...
# 3     جوله علي المدينه القديمه تبليسي شاردن ممتعه ال...
# 4     احلي اجازه لمحبي الطبيعه المناظر الخلابه الطبي...
# ...                                                 ...
# 3195  بصراحة، الغرفة كانت عادية وتفي بالغرض. الاستقب...
# 3196  قمت بتجربة هذا المكان وملاحظاتي هي: أعجبتني ال...
# ...

# %%
#printing amount of 1 , 0 and -1
print(len(all[all['unified_sentiment'] == 1]))
print(len(all[all['unified_sentiment'] == 0]))
print(len(all[all['unified_sentiment'] == -1]))
# Out:
# 9095
# 2388
# 5195

# %%
all.to_csv("Domain_Data.csv")
